# %%
import pandas as pd
import duckdb
# df=pd.read_excel('data/indicadores_actualizado_20250528.xlsx')

# %%
# df[['id_indicador', 'dimension', 'indicador',
#        'estado', 'Origen']].to_csv("data/indicadores_actualizado_20250528.csv", index=False, sep='^')

# %%
df_treemap=pd.read_csv("data/indicadores_actualizado_20250528.csv", sep='^')
# Dimension,Indicador
institucional_df = duckdb.sql("select dimension as 'Dimension', indicador as 'Indicador' from df_treemap where origen='Institucional'").to_df()
institucional_df
# Out:
#                                             Dimension  \
# 0   Dimensión 1: Modelo de Gestión, Costos, Datos,...
# 1   Dimensión 1: Modelo de Gestión, Costos, Datos,...
# 2   Dimensión 1: Modelo de Gestión, Costos, Datos,...
# 3         Dimensión 2: Infraestructura y equipamiento
# 4         Dimensión 2: Infraestructura y equipamiento
# ..                                                ...
# 56  Dimensión 6: Mecanismos de innovación, emprend...
# 57  Dimensión 6: Mecanismos de innovación, emprend...
# 58  Dimensión 6: Mecanismos de innovación, emprend...
# 59  Dimensión 6: Mecanismos de innovación, emprend...
# 60  Dimensión 7: Vinculación, difusión y redes aso...
#
#                                             Indicador
# 0   N° Tesis de pre y postgrado que contribuyen a ...
# 1   Porcentaje de participación de especialistas o...
# 2   Monto total anual asignado en fondos para I+D ...
# 3   N° de laboratorios por Facultad y departamento...
# 4   N° de equipos computacionales de alto rendimie...
# ..                                                ...
# 56  N° de proyectos adjudicados de la Subdirección...
# 57  N° de proyectos adjudicados de la subdirección...
# 58  Nº de Contratos tecnológicos con empresas inte...
# 59  N° de postulaciones a fondos con financiamient...
# 60  Tasa de proyecto externos adjudicados versus p...
#
# [61 rows x 2 columns]
